# %% [markdown]
# # Red neuronal con Regla de Oja

# %% [markdown]
# ### Entrenamiento

# %%
import numpy as np
from get_data import data, raw_data
from Neuron import Neuron
from utils import * 

def update_weigth(eta, s, weights, j):
    return weights + eta * s * (data[j] - s * weights)

def activation(weights, j):
    s = 0
    for i in range(len(data[j])):
        s += data[j][i] * weights[i]
    return s

epochs = 5000
eta = 0.0001

N = len(data)
weight = np.random.uniform(-1, 1, len(data[0]))
w = []
w.append(weight)
for i in range(0, epochs):
    for j in range(0, N):
        s = activation(weight, j)
        weight = update_weigth(eta, s, weight, j)
        w.append(weight)

print("Autovector: ", w[-1])

first_component = np.matmul(data, w[-1])

print("Primera componente: ", first_component)
# Out:
# Autovector:  [ 0.12558938 -0.50044306  0.40722235 -0.48302071  0.18751446 -0.47555222
#   0.27130766]
# Primera componente:  [-1.081053   -0.68123632  2.60918438  1.2679218  -0.16794294 -0.95546069
#   2.48748503 -0.21002428 -0.59177646  0.99755435  1.39667834 -1.58219011
#  -1.80928461 -0.85299031  2.30627702  1.53010659 -3.47781865 -1.84069909
#  -2.10653013  1.47242246  0.52556695  0.78294123  0.06581762 -0.16297478
#  -0.88385638 -3.28259032  4.58499356 -0.34052127]

# %% [markdown]
# ### Visualización de la primer componente por pais

# %%
import numpy as np
import matplotlib.pyplot as plt

print(first_component)

labels = raw_data.values[:,0]

plt.figure(figsize=(40, 20)) 
plt.bar(labels,first_component, width=1, align='center', color='violet', edgecolor = 'black')
plt.plot(np.linspace(-1,28,num=28), np.zeros(len(first_component)), linewidth=2, color='black')
plt.show()
# Out:
# [-1.081053   -0.68123632  2.60918438  1.2679218  -0.16794294 -0.95546069
#   2.48748503 -0.21002428 -0.59177646  0.99755435  1.39667834 -1.58219011
#  -1.80928461 -0.85299031  2.30627702  1.53010659 -3.47781865 -1.84069909
#  -2.10653013  1.47242246  0.52556695  0.78294123  0.06581762 -0.16297478
#  -0.88385638 -3.28259032  4.58499356 -0.34052127]
